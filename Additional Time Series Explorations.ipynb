# %% [markdown]
# ## Wikipedia Web Traffic Via Kaggle
#
# https://www.kaggle.com/c/web-traffic-time-series-forecasting
#
# > **Note**: Due to file size limits on github, the full dataset has been removed from this repository. You can download the full dataset from the Kaggle link listed above. Alternatively, a subset of the dataset has been cached in the `wikipedia-traffic-subset.csv`. The original code for creating this subset is also shown below.

# %%
ls web-traffic-time-series-forecasting/
# Out:
# key_1.csv*               sample_submission_1.csv* train_1.csv*
# key_2.csv*               sample_submission_2.csv* train_2.csv*

# %%
names = pd.read_csv('web-traffic-time-series-forecasting/key_1.csv')
names.head()
# Out:
#                                                 Page            Id
# 0  !vote_en.wikipedia.org_all-access_all-agents_2...  bf4edcf969af
# 1  !vote_en.wikipedia.org_all-access_all-agents_2...  929ed2bf52b9
# 2  !vote_en.wikipedia.org_all-access_all-agents_2...  ff29d0f51d5c
# 3  !vote_en.wikipedia.org_all-access_all-agents_2...  e98873359be6
# 4  !vote_en.wikipedia.org_all-access_all-agents_2...  fa012434263a

# %%
2NE1_zh

# %%
df = pd.read_csv('web-traffic-time-series-forecasting/train_1.csv', nrows=100)
print(df.info())
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 551 entries, Page to 2016-12-31
# dtypes: float64(545), int64(5), object(1)
# memory usage: 430.5+ KB
# None
#                                                 Page  2015-07-01  2015-07-02  \
# 0            2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
# 1             2PM_zh.wikipedia.org_all-access_spider        11.0        14.0
# 2              3C_zh.wikipedia.org_all-access_spider         1.0         0.0
# 3         4minute_zh.wikipedia.org_all-access_spider        35.0        13.0
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN         NaN
#
#    2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  2015-07-08  \
# 0         5.0        13.0        14.0         9.0         9.0        22.0
# 1        15.0        18.0        11.0        13.0        22.0        11.0
# 2         1.0         1.0         0.0         4.0         0.0         3.0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = df.set_index('Page').transpose()
df.head()
# Out:
# Page        2NE1_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     18.0
# 2015-07-02                                     11.0
# 2015-07-03                                      5.0
# 2015-07-04                                     13.0
# 2015-07-05                                     14.0
#
# Page        2PM_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    11.0
# 2015-07-02                                    14.0
# 2015-07-03                                    15.0
# 2015-07-04                                    18.0
# 2015-07-05                                    11.0
#
# Page        3C_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    1.0
# 2015-07-02                                    0.0
# 2015-07-03                                    1.0
# 2015-07-04                                    1.0
# 2015-07-05                                    0.0
#
# ...

# %%
df.index = pd.to_datetime(df.index)
df.head()
# Out:
# Page        2NE1_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     18.0
# 2015-07-02                                     11.0
# 2015-07-03                                      5.0
# 2015-07-04                                     13.0
# 2015-07-05                                     14.0
#
# Page        2PM_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    11.0
# 2015-07-02                                    14.0
# 2015-07-03                                    15.0
# 2015-07-04                                    18.0
# 2015-07-05                                    11.0
#
# Page        3C_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    1.0
# 2015-07-02                                    0.0
# 2015-07-03                                    1.0
# 2015-07-04                                    1.0
# 2015-07-05                                    0.0
#
# ...

# %%
df.head()
# Out:
# Page        2NE1_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     18.0
# 2015-07-02                                     11.0
# 2015-07-03                                      5.0
# 2015-07-04                                     13.0
# 2015-07-05                                     14.0
#
# Page        2PM_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    11.0
# 2015-07-02                                    14.0
# 2015-07-03                                    15.0
# 2015-07-04                                    18.0
# 2015-07-05                                    11.0
#
# Page        3C_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    1.0
# 2015-07-02                                    0.0
# 2015-07-03                                    1.0
# 2015-07-04                                    1.0
# 2015-07-05                                    0.0
#
# ...

# %%
df = df[df.columns[:10]]
df.head()
# Out:
# Page        2NE1_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                     18.0
# 2015-07-02                                     11.0
# 2015-07-03                                      5.0
# 2015-07-04                                     13.0
# 2015-07-05                                     14.0
#
# Page        2PM_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    11.0
# 2015-07-02                                    14.0
# 2015-07-03                                    15.0
# 2015-07-04                                    18.0
# 2015-07-05                                    11.0
#
# Page        3C_zh.wikipedia.org_all-access_spider  \
# 2015-07-01                                    1.0
# 2015-07-02                                    0.0
# 2015-07-03                                    1.0
# 2015-07-04                                    1.0
# 2015-07-05                                    0.0
#
# ...

# %%
df.to_csv('wikipedia-traffic-subset.csv')

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
plt.figure(figsize=(12,10))
df[df.columns[1]].plot()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(df[df.columns[1]], alpha=.05)

# %%
plot_pacf(df[df.columns[1]], alpha=.05, lags=20)

# %%
df[df.columns[1]].diff().plot(figsize=(12,10))

# %%
df[df.columns[1]].diff().shift(periods=365).plot(figsize=(12,10))

# %% [markdown]
# ## UCI
#
# https://archive.ics.uci.edu/ml/datasets/Predict+keywords+activities+in+a+online+social+media
#
# > **Evaluation**: This dataset is apt to be too complex for students. Further work needed before implementing with students.

# %%
ls dataset-keyword-activity/learning-to-rank-dataset/
# Out:
# ALL.csv   HIGH.csv  LOW.csv   MED.csv

# %%
import pandas as pd

# %%
# !head 'dataset-keyword-activity/learning-to-rank-dataset/ALL.csv'
# Out:
# # =========== Multivariate time-series made from twitter ===========
# # Contact / Support : fkawala@techmedianetwork.com ; @FrancoisKawala
# # ==================================================================
# # Original data-set file = ../datasets/twitter/ALL-1+.pikl
# # Target Feature = contr_qty
# # Feature set = ['contr_qty', 'auth_qty_top', 'auth_recru', 'auth_att', 'contr_att']
# # Number of keywords = 1497
# # Number of ranking instances = 51 (cf. Absolute time identifier)
# # Feature per column post-fixed with relative time of observation:
# ...

# %%
df = pd.read_csv('dataset-keyword-activity/learning-to-rank-dataset/ALL.csv', delimiter=';', skiprows=9)
df.head()
# Out:
#    # activity_0   activity_1   activity_2   activity_3   activity_4  \
# 0        1002.0        925.0       1105.0        973.0        889.0
# 1         805.0        805.0       1143.0       1121.0        954.0
# 2         542.0        473.0        504.0        626.0        647.0
# 3        1406.0        947.0        363.0        180.0         92.0
# 4         100.0        184.0         79.0        162.0         99.0
#
#     activity_5   activity_6   number_of_users_0   number_of_users_1  \
# 0        939.0        960.0               661.0               587.0
# 1        911.0        777.0               503.0               478.0
# 2        795.0        832.0               414.0               351.0
# 3         99.0        196.0              1162.0               589.0
# 4         98.0        264.0                73.0               144.0
#
#     number_of_users_2   ...     attention_level_number_of_users_6  \
# 0               767.0   ...                              0.000757
# ...
